# %%
# %matplotlib qt
import mne
import numpy as np
import os.path as op
import matplotlib.pyplot as plt

# %% [markdown]
# # Read sample data

# %%
data_path = op.expanduser('~/data/wash-u/REST18_20_MZ_Best/')
fname_raw = '7005_4_rest1_ec.cnt'
fpath_raw = op.join(data_path, fname_raw)
raw = mne.io.read_raw_cnt(fpath_raw, eog='auto', ecg=['EKG'])
raw.info
# Out:
# /var/folders/8s/6ch1361n4dz5r08lps2_3d_n34sk04/T/ipykernel_37248/2410971870.py:4: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = mne.io.read_raw_cnt(fpath_raw, eog='auto', ecg=['EKG'])
# /var/folders/8s/6ch1361n4dz5r08lps2_3d_n34sk04/T/ipykernel_37248/2410971870.py:4: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   raw = mne.io.read_raw_cnt(fpath_raw, eog='auto', ecg=['EKG'])
# <Info | 8 non-empty values
#  bads: []
#  ch_names: O2, O1, Pz, P4, P8, C4, T8, P7, P3, Cz, C3, Fz, F4, F8, T7, F3, ...
#  chs: 31 EEG, 1 ECG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 34
#  projs: []
#  sfreq: 500.0 Hz
#  subject_info: 5 items (dict)
# >

# %% [markdown]
# # Visually inspect data for bad channels and spans

# %%
# Visually inspect raw data and mark bad channels and span
# raw.plot(n_channels=len(raw))

# %%
# Interpolate bad channel data
# raw.interpolate_bads()

# %% [markdown]
# # Channel locations

# %%
# fig2 = raw.plot_sensors(show_names=True)
# raw.plot_sensors('3d')

# %% [markdown]
# # Use ICA to remove ocular and cardiac artifacts

# %%
# eog_evoked = mne.preprocessing.create_eog_epochs(raw).average()
# eog_evoked.apply_baseline(baseline=(None, -0.2))
# fig6 = eog_evoked.plot_joint()

# %%
# Load data into memory
raw.load_data()

# Filtering to remove slow drifts
filt_raw_ica = raw.copy().filter(l_freq=1, h_freq=None)

# Fitting the ICA solution
ica = mne.preprocessing.ICA(n_components=30, max_iter='auto', random_state=97)
ica.fit(filt_raw_ica)
ica
# Out:
# Reading 0 ... 155879  =      0.000 ...   311.758 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 1651 samples (3.302 sec)
#
# Fitting ICA to data using 31 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.1s finished
# Selecting by number: 30 components
# Fitting ICA took 4.5s.
# <ICA | raw data decomposition, method: fastica (fit in 56 iterations on 155880 samples), 30 ICA components explaining 100.0 % of variance (31 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
# Plotting the ICA solution
fig7 = ica.plot_sources(raw, show_scrollbars=True)

# Visualize the scalp field distribution of ICA components
fig8 = ica.plot_components()
# Out:
# Creating RawArray with float64 data, n_channels=33, n_times=155880
#     Range : 0 ... 155879 =      0.000 ...   311.758 secs
# Ready.

# %%
# Additional visualization to check exclusion criteria
fig9 = ica.plot_overlay(raw, exclude=[2, 20])
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (30 components)
#     Zeroing out 2 ICA components
#     Projecting back using 31 PCA components

# %%
# Manual selection of ICA components to be excluded
ica.exclude = [2, 20]

# Reconstruction of raw data after ICA exclusion
reconst_raw = raw.copy()
ica.apply(reconst_raw)

# Visualize repair
fig10 = raw.plot(n_channels=len(raw), show_scrollbars=False)
fig11 = reconst_raw.plot(n_channels=len(raw), show_scrollbars=False)
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (30 components)
#     Zeroing out 2 ICA components
#     Projecting back using 31 PCA components
# Channels marked as bad:
# none
# Channels marked as bad:
# none

# %%
# Export preprocessed data to a new .fif file
fname_reconst_raw = fname_raw[:-4] + '_eeg.fif'
fpath_reconst_raw = op.join(data_path, '../preprocessed/', fname_reconst_raw)
reconst_raw.save(fpath_reconst_raw, overwrite=True)
# Out:
# Writing /Users/chholakp2/data/wash-u/REST18_20_MZ_Best/../preprocessed/7005_4_rest1_ec_preprocessed_eeg1.fif
# Closing /Users/chholakp2/data/wash-u/REST18_20_MZ_Best/../preprocessed/7005_4_rest1_ec_preprocessed_eeg1.fif
# [done]
# /var/folders/8s/6ch1361n4dz5r08lps2_3d_n34sk04/T/ipykernel_37248/3216626828.py:4: RuntimeWarning: This filename (/Users/chholakp2/data/wash-u/REST18_20_MZ_Best/../preprocessed/7005_4_rest1_ec_preprocessed_eeg1.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   reconst_raw.save(fpath_reconst_raw, overwrite=True)
