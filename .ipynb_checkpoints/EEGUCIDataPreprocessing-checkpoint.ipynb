# %%
# %matplotlib qt
import mne
import time
import os
import os.path as op
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/Users/chholakp2/data/aud-mne/'
events_dict = {"s1": 1, "s2/match": 2, "s2/nomatch": 3}

# %%
dir_entries = os.scandir(data_path)
subj_names = [entry.name for entry in dir_entries if entry.is_dir()] # unsorted

# %%
# Start clocking execution
startTime = time.time()

evokeds = []
for subj_name in subj_names:
    # Read epochs data for each subject
    fpath_epx = op.join(data_path, subj_name, subj_name + '-epo.fif')
    epochs = mne.read_epochs(fpath_epx)

    # Bandpass filter
    epochs.filter(l_freq=0.02, h_freq=50)
    
    # Get evoked data from events of interest
    epochs.event_id = events_dict
#     ev_c1 = epochs["s1"].average()
    ev_c2 = epochs["s2/match"].average()
#     ev_c3 = epochs["s2/nomatch"].average()
    evokeds.append(ev_c2)
    
# End clocking execution and display result
executionTime = (time.time() - startTime)
print('Execution time in seconds:', str(executionTime))
# Out:
# /Users/chholakp2/data/aud-mne/hcv-099/hcv-099-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-099/hcv-099-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-097/hcv-097-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-097/hcv-097-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-090/hcv-090-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-090/hcv-090-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-091/hcv-091-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-091/hcv-091-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 106 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-096/hcv-096-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-096/hcv-096-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 105 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-098/hcv-098-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-098/hcv-098-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-048/aud-048-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-048/aud-048-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-046/aud-046-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-046/aud-046-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-041/aud-041-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-041/aud-041-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 101 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-015/aud-015-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-015/aud-015-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-012/aud-012-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-012/aud-012-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-024/aud-024-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-024/aud-024-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 77 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-023/aud-023-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-023/aud-023-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-040/aud-040-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-040/aud-040-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-047/aud-047-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-047/aud-047-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-049/aud-049-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-049/aud-049-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-022/aud-022-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-022/aud-022-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 111 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-025/aud-025-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-025/aud-025-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 96 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-013/aud-013-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-013/aud-013-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 104 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-014/aud-014-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-014/aud-014-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 114 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-009/aud-009-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-009/aud-009-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-102/hcv-102-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-102/hcv-102-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 41 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-036/aud-036-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-036/aud-036-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-105/hcv-105-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-105/hcv-105-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 85 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-031/aud-031-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-031/aud-031-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-038/aud-038-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-038/aud-038-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-007/aud-007-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-007/aud-007-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 115 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-054/aud-054-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-054/aud-054-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-053/aud-053-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-053/aud-053-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 104 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-065/aud-065-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-065/aud-065-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 93 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-062/aud-062-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-062/aud-062-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 83 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-001/aud-001-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-001/aud-001-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-039/aud-039-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-039/aud-039-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 85 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-006/aud-006-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-006/aud-006-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 106 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-030/aud-030-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-030/aud-030-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-104/hcv-104-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-104/hcv-104-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 109 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-008/aud-008-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-008/aud-008-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 85 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-037/aud-037-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-037/aud-037-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 115 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-103/hcv-103-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-103/hcv-103-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-063/aud-063-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-063/aud-063-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-064/aud-064-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-064/aud-064-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-052/aud-052-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-052/aud-052-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 108 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-055/aud-055-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-055/aud-055-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-118/aud-118-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-118/aud-118-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 101 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-120/aud-120-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-120/aud-120-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 116 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-116/aud-116-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-116/aud-116-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-111/aud-111-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-111/aud-111-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 119 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-085/hcv-085-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-085/hcv-085-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 110 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-071/hcv-071-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-071/hcv-071-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 115 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-076/hcv-076-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-076/hcv-076-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-082/hcv-082-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-082/hcv-082-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-078/hcv-078-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-078/hcv-078-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-110/aud-110-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-110/aud-110-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-117/aud-117-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-117/aud-117-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-121/aud-121-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-121/aud-121-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-119/aud-119-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-119/aud-119-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-079/hcv-079-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-079/hcv-079-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 92 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-083/hcv-083-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-083/hcv-083-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 69 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-077/hcv-077-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-077/hcv-077-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 92 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-070/hcv-070-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-070/hcv-070-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-084/hcv-084-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-084/hcv-084-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 83 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-069/hcv-069-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-069/hcv-069-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 83 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-067/hcv-067-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-067/hcv-067-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 104 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-093/hcv-093-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-093/hcv-093-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-094/hcv-094-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-094/hcv-094-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-095/hcv-095-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-095/hcv-095-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 109 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-092/hcv-092-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-092/hcv-092-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 78 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-066/hcv-066-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-066/hcv-066-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 78 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-068/hcv-068-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-068/hcv-068-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-011/aud-011-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-011/aud-011-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 108 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-016/aud-016-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-016/aud-016-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-122/hcv-122-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-122/hcv-122-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 111 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-029/aud-029-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-029/aud-029-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 96 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-020/aud-020-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-020/aud-020-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 104 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-027/aud-027-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-027/aud-027-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 92 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-018/aud-018-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-018/aud-018-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 67 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-042/aud-042-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-042/aud-042-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 117 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-045/aud-045-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-045/aud-045-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 77 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-026/aud-026-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-026/aud-026-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 78 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-019/aud-019-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-019/aud-019-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-021/aud-021-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-021/aud-021-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 96 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-017/aud-017-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-017/aud-017-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-028/aud-028-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-028/aud-028-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 97 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-010/aud-010-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-010/aud-010-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 112 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-044/aud-044-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-044/aud-044-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-043/aud-043-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-043/aud-043-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-050/aud-050-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-050/aud-050-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-057/aud-057-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-057/aud-057-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 109 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-061/aud-061-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-061/aud-061-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 92 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-059/aud-059-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-059/aud-059-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 101 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-106/hcv-106-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-106/hcv-106-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 104 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-032/aud-032-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-032/aud-032-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 93 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-101/hcv-101-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-101/hcv-101-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-035/aud-035-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-035/aud-035-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 94 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-108/hcv-108-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-108/hcv-108-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-003/aud-003-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-003/aud-003-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-004/aud-004-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-004/aud-004-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 118 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-058/aud-058-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-058/aud-058-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 111 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-060/aud-060-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-060/aud-060-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-056/aud-056-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-056/aud-056-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-051/aud-051-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-051/aud-051-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-005/aud-005-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-005/aud-005-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 118 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-109/hcv-109-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-109/hcv-109-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 103 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-002/aud-002-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-002/aud-002-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 93 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-034/aud-034-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-034/aud-034-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 110 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-100/hcv-100-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-100/hcv-100-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-033/aud-033-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-033/aud-033-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 106 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-107/hcv-107-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-107/hcv-107-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 57 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-075/hcv-075-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-075/hcv-075-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-081/hcv-081-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-081/hcv-081-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-086/hcv-086-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-086/hcv-086-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-072/hcv-072-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-072/hcv-072-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 93 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-088/hcv-088-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-088/hcv-088-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 107 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-112/aud-112-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-112/aud-112-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 117 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-115/aud-115-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-115/aud-115-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-089/hcv-089-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-089/hcv-089-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-073/hcv-073-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-073/hcv-073-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 112 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-087/hcv-087-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-087/hcv-087-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-080/hcv-080-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-080/hcv-080-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 67 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/hcv-074/hcv-074-epo.fif
# Reading /Users/chholakp2/data/aud-mne/hcv-074/hcv-074-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 112 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-114/aud-114-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-114/aud-114-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/chholakp2/data/aud-mne/aud-113/aud-113-epo.fif
# Reading /Users/chholakp2/data/aud-mne/aud-113/aud-113-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...     996.09 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 86 matching events found
# No baseline correction applied
# 0 projection items activated
# Execution time in seconds: 3.5064430236816406

# %%
ev_grand_av = mne.grand_average(evokeds)
# Out:
# Identifying common channels ...

# %%
print(ev_grand_av)
# Out:
# <Evoked | 'Grand average (n = 122)' (average, N=122), 0 – 0.99609 sec, baseline off, 64 ch, ~196 kB>

# %%
ev_grand_av.plot()

# %%
epochs.filter(l_freq=0.02, h_freq=50)
# Out:
# Setting up band-pass filter from 0.02 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.02
# - Lower transition bandwidth: 0.02 Hz (-6 dB cutoff frequency: 0.01 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 42241 samples (165.004 sec)
# /var/folders/8s/6ch1361n4dz5r08lps2_3d_n34sk04/T/ipykernel_89334/2252262057.py:1: RuntimeWarning: filter_length (42241) is longer than the signal (256), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(l_freq=0.02, h_freq=50)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 5504 out of 5504 | elapsed:    9.0s finished
# <EpochsFIF |  86 events (all good), 0 - 0.996094 sec, baseline off, ~10.8 MB, data loaded,
#  's1': 48
#  's2/match': 18
#  's2/nomatch': 20>

# %%
epochs.plot_psd(fmax=50, average=True)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# <MNELineFigure size 1000x350 with 1 Axes>
